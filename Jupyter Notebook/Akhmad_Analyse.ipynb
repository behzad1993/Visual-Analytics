# %%
import sys
sys.path.append('../gummistiefel')

# %%
import request_tool # from gummistiefel directory
import graph_tool   # from gummistiefel directory

# %%
parameters = [
    "length(20,100)",
    "si(0.1,0.3)",
    "area(2,5)"
]

# %%
df = request_tool.getDataframeFromServer(parameters, fullData=True)
df
# Out:
#      event_area           event_date   event_id  event_lat  event_latMax  \
# 0          0.21  1981-07-24T19:00:00  198103100  49.930000     49.880001
# 1          0.27  1981-07-24T20:00:00  198103100  50.290001     50.330002
# 2          0.36  1981-07-24T21:00:00  198103100  50.689999     50.669998
# 3          0.49  1981-07-24T22:00:00  198103100  51.070000     51.119999
# 4          0.60  1981-07-24T23:00:00  198103100  51.419998     51.459999
# ..          ...                  ...        ...        ...           ...
# 970        0.15  2017-06-29T20:00:00  201702445  52.259998     52.349998
# 971        0.19  2017-06-29T21:00:00  201702445  52.430000     52.470001
# 972        0.19  2017-06-29T22:00:00  201702445  52.560001     52.580002
# 973        0.10  2017-06-29T23:00:00  201702445  52.669998     52.689999
# 974        0.03  2017-06-30T00:00:00  201702445  52.689999     52.689999
#
#      event_lon  event_lonMax  event_maxPrec  event_meanPre  event_si  \
# ...

# %%
fig = graph_tool.getGraph(df, x_column='event_date',y_column='event_lat')
fig.show()

# %%
fig = graph_tool.getMap(df)
fig.show()
